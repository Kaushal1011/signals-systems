# %%
import numpy as np
def main():
    A4_octave = [130.81278265]
    for _ in range(11):
        A4_octave.append(A4_octave[-1] * 2**(1 / 12))
    A4_octave = np.array(A4_octave)
    return np.array([A4_octave / 8,
                     A4_octave / 4,
                     A4_octave / 2,
                     A4_octave,
                     A4_octave * 2,
                     A4_octave * 4,
                     A4_octave * 8,
                     A4_octave * 16])

# %%
from pprint import pprint
x = main()
freq = {}
for i in range(8):
    freq[i] = x[i]
pprint(freq)
# Out:
# {0: array([16.35159783, 17.32391444, 18.35404799, 19.44543648, 20.60172231,
#        21.82676446, 23.12465142, 24.49971475, 25.9565436 , 27.5       ,
#        29.13523509, 30.86770633]),
#  1: array([32.70319566, 34.64782887, 36.70809599, 38.89087297, 41.20344461,
#        43.65352893, 46.24930284, 48.9994295 , 51.9130872 , 55.        ,
#        58.27047019, 61.73541266]),
#  2: array([ 65.40639133,  69.29565774,  73.41619198,  77.78174593,
#         82.40688923,  87.30705786,  92.49860568,  97.998859  ,
#        103.82617439, 110.        , 116.54094038, 123.47082531]),
#  3: array([130.81278265, 138.59131549, 146.83238396, 155.56349186,
#        164.81377846, 174.61411572, 184.99721136, 195.99771799,
#        207.65234879, 220.        , 233.08188076, 246.94165063]),
#  4: array([261.6255653 , 277.18263098, 293.66476792, 311.12698372,
#        329.62755691, 349.22823143, 369.99442271, 391.99543598,
#        415.30469758, 440.        , 466.16376152, 493.88330125]),
#  5: array([523.2511306 , 554.36526195, 587.32953583, 622.25396744,
#        659.25511382, 698.45646286, 739.98884542, 783.99087196,
#        830.60939516, 880.        , 932.32752303, 987.76660251]),
#  6: array([1046.5022612 , 1108.7305239 , 1174.65907167, 1244.50793489,
#        1318.51022765, 1396.91292573, 1479.97769084, 1567.98174392,
#        1661.21879032, 1760.        , 1864.65504607, 1975.53320502]),
#  7: array([2093.0045224 , 2217.46104781, 2349.31814333, 2489.01586977,
#        2637.0204553 , 2793.82585146, 2959.95538169, 3135.96348785,
#        3322.43758063, 3519.99999999, 3729.31009214, 3951.06641004])}

# %%
notes = []
